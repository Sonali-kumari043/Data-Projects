# %% [markdown]
# # US-accidents-analysis
#
# Use the "Run" button to execute the code.

# %%
## US ACCIDENTS EXPLORATORY DATA ANALYSIS

# %% [markdown]
# TODO- talk abpout EDA
# This does not contain data for New York
# TODO- talk about the dataset (Source, what it contains, how it will be useful)
# - Kaggle
# - information about accidents
# - can be useful to prevent accidents

# %% [markdown]
# Download Dataset
# Add data in input in kaggle
# if you are using opendataset or anything else, use kaggle API key

# %%
datafile_name = "/kaggle/input/us-accidents/US_Accidents_March23.csv"

# %% [markdown]
# Data Prepration and Cleaning
#
# TODO
# *     - Load the file using pandas
#     - Look at some information about the data & columns
#     - Fix any missing and incorrect value

# %%
# !pip install pandas --quiet

# %%
import pandas as pd

# %%
df = pd.read_csv(datafile_name)

# %%
df
# Out:
#                 ID   Source  Severity           Start_Time  \
# 0              A-1  Source2         3  2016-02-08 05:46:00
# 1              A-2  Source2         2  2016-02-08 06:07:59
# 2              A-3  Source2         2  2016-02-08 06:49:27
# 3              A-4  Source2         3  2016-02-08 07:23:34
# 4              A-5  Source2         2  2016-02-08 07:39:07
# ...            ...      ...       ...                  ...
# 7728389  A-7777757  Source1         2  2019-08-23 18:03:25
# 7728390  A-7777758  Source1         2  2019-08-23 19:11:30
# 7728391  A-7777759  Source1         2  2019-08-23 19:00:21
# 7728392  A-7777760  Source1         2  2019-08-23 19:00:21
# 7728393  A-7777761  Source1         2  2019-08-23 18:52:06
#
#                     End_Time  Start_Lat   Start_Lng   End_Lat    End_Lng  \
# 0        2016-02-08 11:00:00  39.865147  -84.058723       NaN        NaN
# 1        2016-02-08 06:37:59  39.928059  -82.831184       NaN        NaN
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Source', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat',
#        'Start_Lng', 'End_Lat', 'End_Lng', 'Distance(mi)', 'Description',
#        'Street', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 46

# %%
len(df)
# Out:
# 7728394

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7728394 entries, 0 to 7728393
# Data columns (total 46 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Source                 object
#  2   Severity               int64
#  3   Start_Time             object
#  4   End_Time               object
#  5   Start_Lat              float64
#  6   Start_Lng              float64
#  7   End_Lat                float64
#  8   End_Lng                float64
#  9   Distance(mi)           float64
#  10  Description            object
#  11  Street                 object
#  12  City                   object
#  13  County                 object
#  14  State                  object
#  15  Zipcode                object
#  16  Country                object
#  17  Timezone               object
#  18  Airport_Code           object
#  19  Weather_Timestamp      object
#  20  Temperature(F)         float64
# ...

# %%
df.describe()
# Out:
#            Severity     Start_Lat     Start_Lng       End_Lat       End_Lng  \
# count  7.728394e+06  7.728394e+06  7.728394e+06  4.325632e+06  4.325632e+06
# mean   2.212384e+00  3.620119e+01 -9.470255e+01  3.626183e+01 -9.572557e+01
# std    4.875313e-01  5.076079e+00  1.739176e+01  5.272905e+00  1.810793e+01
# min    1.000000e+00  2.455480e+01 -1.246238e+02  2.456601e+01 -1.245457e+02
# 25%    2.000000e+00  3.339963e+01 -1.172194e+02  3.346207e+01 -1.177543e+02
# 50%    2.000000e+00  3.582397e+01 -8.776662e+01  3.618349e+01 -8.802789e+01
# 75%    2.000000e+00  4.008496e+01 -8.035368e+01  4.017892e+01 -8.024709e+01
# max    4.000000e+00  4.900220e+01 -6.711317e+01  4.907500e+01 -6.710924e+01
#
#        Distance(mi)  Temperature(F)  Wind_Chill(F)   Humidity(%)  \
# count  7.728394e+06    7.564541e+06   5.729375e+06  7.554250e+06
# mean   5.618423e-01    6.166329e+01   5.825105e+01  6.483104e+01
# std    1.776811e+00    1.901365e+01   2.238983e+01  2.282097e+01
# ...

# %%
numeric_df = df.select_dtypes (include = [int, float])
len(numeric_df.columns)
# Out:
# 13

# %% [markdown]
# percentage of missing values per column

# %%
missing_percentages = df.isna().sum().sort_values(ascending= False) / len(df)
missing_percentages
# Out:
# End_Lat                  4.402935e-01
# End_Lng                  4.402935e-01
# Precipitation(in)        2.851286e-01
# Wind_Chill(F)            2.586590e-01
# Wind_Speed(mph)          7.391355e-02
# Visibility(mi)           2.291524e-02
# Wind_Direction           2.267043e-02
# Humidity(%)              2.253301e-02
# Weather_Condition        2.244438e-02
# Temperature(F)           2.120143e-02
# Pressure(in)             1.820288e-02
# Weather_Timestamp        1.555666e-02
# Nautical_Twilight        3.007869e-03
# Civil_Twilight           3.007869e-03
# Sunrise_Sunset           3.007869e-03
# Astronomical_Twilight    3.007869e-03
# Airport_Code             2.928810e-03
# Street                   1.406372e-03
# Timezone                 1.010300e-03
# Zipcode                  2.477876e-04
# City                     3.273643e-05
# Description              6.469649e-07
# Traffic_Signal           0.000000e+00
# Roundabout               0.000000e+00
# Station                  0.000000e+00
# ...

# %%
type(missing_percentages)
# Out:
# pandas.core.series.Series

# %%
missing_percentages[missing_percentages!=0].plot(kind = "barh")
# Out:
# <Axes: >

# %% [markdown]
# Remove the columns you don't want to use

# %% [markdown]
# Exploratory Analyis and Visualization
# Columns we will analyze:
# - City
# - Srat Time
# - Srat lat,Start Long
# - Temperature
# - Weather Condition

# %%
df.columns
# Out:
# Index(['ID', 'Source', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat',
#        'Start_Lng', 'End_Lat', 'End_Lng', 'Distance(mi)', 'Description',
#        'Street', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %% [markdown]
# ### City

# %%
cities = df.City.unique()
len(cities)
# Out:
# 13679

# %%
cities_by_accidents = df.City.value_counts()
cities_by_accidents
# Out:
# City
# Miami                           186917
# Houston                         169609
# Los Angeles                     156491
# Charlotte                       138652
# Dallas                          130939
#                                  ...
# Benkelman                            1
# Old Appleton                         1
# Wildrose                             1
# Mc Nabb                              1
# American Fork-Pleasant Grove         1
# Name: count, Length: 13678, dtype: int64

# %%
cities_by_accidents.head(20) ## cities_by_accidents[:10]
# Out:
# City
# Miami            186917
# Houston          169609
# Los Angeles      156491
# Charlotte        138652
# Dallas           130939
# Orlando          109733
# Austin            97359
# Raleigh           86079
# Nashville         72930
# Baton Rouge       71588
# Atlanta           68186
# Sacramento        66264
# San Diego         55504
# Phoenix           53974
# Minneapolis       51488
# Richmond          48845
# Oklahoma City     46092
# Jacksonville      42447
# Tucson            39304
# Columbia          38178
# Name: count, dtype: int64

# %%
cities_by_accidents.head(20).plot(kind= "barh");

# %%
import seaborn as sns
sns.set_style("darkgrid")

# %%
type(cities_by_accidents)
# Out:
# pandas.core.series.Series

# %%
sns.distplot(cities_by_accidents);
# Out:
# /tmp/ipykernel_33/2270598693.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cities_by_accidents);
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
high_accident_cities= cities_by_accidents[cities_by_accidents>= 1000]
high_accident_cities
# Out:
# City
# Miami            186917
# Houston          169609
# Los Angeles      156491
# Charlotte        138652
# Dallas           130939
#                   ...
# Fairview           1002
# Sedona             1001
# Zephyrhills        1000
# Berwyn             1000
# Bennettsville      1000
# Name: count, Length: 1218, dtype: int64

# %%
low_accident_cities= cities_by_accidents[cities_by_accidents <1000]
low_accident_cities
# Out:
# City
# Coos Bay                        998
# Hobe Sound                      996
# Thousand Oaks                   995
# Polk City                       994
# Roosevelt                       994
#                                ...
# Benkelman                         1
# Old Appleton                      1
# Wildrose                          1
# Mc Nabb                           1
# American Fork-Pleasant Grove      1
# Name: count, Length: 12460, dtype: int64

# %%
len(high_accident_cities)/len(cities)
# Out:
# 0.08904159660793917

# %%
len(low_accident_cities)/len(cities)
# Out:
# 0.910885298632941

# %%
sns.distplot(high_accident_cities);
# Out:
# /tmp/ipykernel_33/1339922581.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(high_accident_cities);
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.histplot(cities_by_accidents, log_scale = True);
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
cities_by_accidents[cities_by_accidents ==1]
# Out:
# City
# Lake Andes                      1
# Catoctin                        1
# Duck Hill                       1
# Westbrookville                  1
# Saint Croix                     1
#                                ..
# Benkelman                       1
# Old Appleton                    1
# Wildrose                        1
# Mc Nabb                         1
# American Fork-Pleasant Grove    1
# Name: count, Length: 1023, dtype: int64

# %% [markdown]
# ### Start Time

# %%
type(df.Start_Time)
# Out:
# pandas.core.series.Series

# %%
df.Start_Time
# Out:
# 0          2016-02-08 05:46:00
# 1          2016-02-08 06:07:59
# 2          2016-02-08 06:49:27
# 3          2016-02-08 07:23:34
# 4          2016-02-08 07:39:07
#                   ...
# 7728389    2019-08-23 18:03:25
# 7728390    2019-08-23 19:11:30
# 7728391    2019-08-23 19:00:21
# 7728392    2019-08-23 19:00:21
# 7728393    2019-08-23 18:52:06
# Name: Start_Time, Length: 7728394, dtype: object

# %%
df.iloc[3639787]
# Out:
# ID                                               A-3649670
# Source                                             Source1
# Severity                                                 2
# Start_Time                   2017-07-23 14:50:17.000000000
# End_Time                     2017-07-23 20:50:17.000000000
# Start_Lat                                         37.55188
# Start_Lng                                      -122.512145
# End_Lat                                           37.55188
# End_Lng                                        -122.512145
# Distance(mi)                                           0.0
# Description              At Tom Lantos Tunnels - Accident.
# Street                                        Cabrillo Hwy
# City                                            Moss Beach
# County                                           San Mateo
# State                                                   CA
# Zipcode                                              94038
# ...

# %% [markdown]
# figure out how to show percentages

# %%
df.Start_Time = pd.to_datetime(df.Start_Time, format="ISO8601")
df.Start_Time.dt.hour
# Out:
# 0           5
# 1           6
# 2           6
# 3           7
# 4           7
#            ..
# 7728389    18
# 7728390    19
# 7728391    19
# 7728392    19
# 7728393    18
# Name: Start_Time, Length: 7728394, dtype: int32

# %%
sns.distplot(df.Start_Time.dt.hour, bins = 24, kde = False, norm_hist = True);
# Out:
# /tmp/ipykernel_33/3254709380.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Start_Time.dt.hour, bins = 24, kde = False, norm_hist = True);

# %% [markdown]
# A high Percentage of accident occur between 6-10 am and 4-7 pm (probably people in hurry to get to work or home)

# %%
sns.distplot(df.Start_Time.dt.dayofweek, bins = 7, kde = False, norm_hist = True);
# Out:
# /tmp/ipykernel_33/3321668851.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Start_Time.dt.dayofweek, bins = 7, kde = False, norm_hist = True);

# %% [markdown]
# is the distribution of accident by hour same on weekends as weekdays

# %%
sunday_Start_Time = df.Start_Time[df.Start_Time.dt.dayofweek == 6 ]

# %%
sns.distplot(sunday_Start_Time.dt.hour, bins = 24, kde = False, norm_hist = True);
# Out:
# /tmp/ipykernel_33/1520822772.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(sunday_Start_Time.dt.hour, bins = 24, kde = False, norm_hist = True);

# %%
monday_Start_Time = df.Start_Time[df.Start_Time.dt.dayofweek == 0 ]
sns.distplot(monday_Start_Time.dt.hour, bins = 24, kde = False, norm_hist = True);
# Out:
# /tmp/ipykernel_33/937921994.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(monday_Start_Time.dt.hour, bins = 24, kde = False, norm_hist = True);

# %% [markdown]
# On sundays, peak occur b/w 12-3 pm unlike week days

# %%
sns.distplot(df.Start_Time.dt.month, bins = 12, kde = False, norm_hist = True);
# Out:
# /tmp/ipykernel_33/794304166.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Start_Time.dt.month, bins = 12, kde = False, norm_hist = True);

# %%
df_2019 = df.Start_Time[df.Start_Time.dt.year == 2019]
df_2019
# Out:
# 1565463   2019-12-26 17:09:52
# 1565464   2019-12-26 17:10:32
# 1664236   2019-12-31 23:49:36
# 1664238   2019-12-31 23:50:02
# 1664303   2019-12-31 23:29:03
#                   ...
# 7728389   2019-08-23 18:03:25
# 7728390   2019-08-23 19:11:30
# 7728391   2019-08-23 19:00:21
# 7728392   2019-08-23 19:00:21
# 7728393   2019-08-23 18:52:06
# Name: Start_Time, Length: 954303, dtype: datetime64[ns]

# %% [markdown]
# much data is missing for 2016 and 2017

# %%
sns.distplot(df_2019.dt.month, bins = 12, kde = False, norm_hist = True);
# Out:
# /tmp/ipykernel_33/2471566576.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_2019.dt.month, bins = 12, kde = False, norm_hist = True);

# %%
df_2016 = df.Start_Time[df.Start_Time.dt.year == 2016]

sns.distplot(df_2016.dt.month, bins = 12, kde = False, norm_hist = True);
# Out:
# /tmp/ipykernel_33/2539713207.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_2016.dt.month, bins = 12, kde = False, norm_hist = True);

# %%
df.Source
# Out:
# 0          Source2
# 1          Source2
# 2          Source2
# 3          Source2
# 4          Source2
#             ...
# 7728389    Source1
# 7728390    Source1
# 7728391    Source1
# 7728392    Source1
# 7728393    Source1
# Name: Source, Length: 7728394, dtype: object

# %%
df.Source.value_counts().plot(kind ="pie");

# %% [markdown]
# Consider excluding bing data as it seema a little off

# %% [markdown]
# ## Start Latitude and Longitude

# %%
df.Start_Lat
# Out:
# 0          39.865147
# 1          39.928059
# 2          39.063148
# 3          39.747753
# 4          39.627781
#              ...
# 7728389    34.002480
# 7728390    32.766960
# 7728391    33.775450
# 7728392    33.992460
# 7728393    34.133930
# Name: Start_Lat, Length: 7728394, dtype: float64

# %%
df.Start_Lng
# Out:
# 0          -84.058723
# 1          -82.831184
# 2          -84.032608
# 3          -84.205582
# 4          -84.188354
#               ...
# 7728389   -117.379360
# 7728390   -117.148060
# 7728391   -117.847790
# 7728392   -118.403020
# 7728393   -117.230920
# Name: Start_Lng, Length: 7728394, dtype: float64

# %%
sample_df = df.sample(int(0.1 * len(df)))
sns.scatterplot(x= sample_df.Start_Lng, y= sample_df.Start_Lat, size = 0.001);

# %%
import folium

# %%
from folium import plugins
from folium.plugins import HeatMap

# %%
Lat,Lng = df.Start_Lat[0], df.Start_Lng[0]
Lat,Lng
# Out:
# (39.865147, -84.058723)

# %%
sample_df = df.sample(int(0.01* len(df)))

location = list(zip(list(sample_df.Start_Lat), list(sample_df.Start_Lng)))
location[:100]
# Out:
# [(39.068939, -121.672058),
#  (38.76115, -90.099029),
#  (34.992798, -81.842453),
#  (33.482029, -111.987022),
#  (28.109811, -82.74344),
#  (33.764876, -84.519733),
#  (33.82516, -118.21831),
#  (32.923473, -97.078812),
#  (29.753362, -82.493443),
#  (41.34568, -73.651772),
#  (36.206105, -86.77138599999998),
#  (32.840561, -97.314049),
#  (26.841738, -80.130928),
#  (36.984119, -122.030137),
#  (34.005749, -117.966957),
#  (36.14129662, -86.73185706),
#  (34.030571, -118.031914),
#  (28.450757, -81.463059),
#  (39.277775, -76.615623),
#  (45.116318, -93.193318),
#  (48.341862, -102.860853),
#  (47.869003, -122.277061),
#  (30.26902, -97.749855),
#  (30.572975, -87.291836),
#  (34.978802, -82.057854),
#  (43.097424, -83.604187),
#  (33.743347, -118.29892),
#  (45.108672, -95.906151),
#  (35.159481, -80.920563),
#  (34.049397, -118.263992),
#  (39.527428, -119.783997),
#  (33.5387, -112.112266),
#  (42.201869, -79.935191),
#  (40.667072, -73.995743),
#  (30.514931, -91.173092),
# ...

# %%
map = folium.Map()
HeatMap(location).add_to(map)
map

# %% [markdown]
# Ask and Answer Question
# - Are there more accidents in warmer or colder area
# - which states have the highest no. of accidents
# - how about per capita
# - Does New York show up in the data if yes, why is the count low if it is the most populus city
# - Among the top 100 cities, which state do they belong
# - What time of day are aacodents more frequent in
# - Which days of week have most accidents
# - which month have highest no. of accident
# - trend of accident per day
# - when is the accident per unit of traffic is highest

# %%
'New York' in df.City
# Out:
# False

# %%
'NY' in df.State
# Out:
# False

# %% [markdown]
# Summary and Conclusion:
# - No data for New York
# - the no. of accidents per city decreases/ increases exponentially
# - less than 5% cities have more than yearly 1000 accidents in these years
# - Over 1023 cities has reported just 1 accident (need to investigate)
# - A high Percentage of accident occur between 6-10 am (probably people in hurry to get to work)
# - there seems to be some issues with bing data
# - Coastal areas have more accidents
